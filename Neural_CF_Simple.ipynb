# %%
import torch

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
from torch.nn import Module
from torch.utils.data import Dataset, DataLoader
from scipy.sparse import coo_matrix
from scipy.sparse import vstack
from scipy import sparse
import numpy as np
import pandas as pd
from torch.optim import Adam
from torch.nn import MSELoss
import time

np.random.seed(2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data Processing

# %%
class RatingsDataset(Dataset):
    """Ratings Dataset"""

    def __init__(self):
        """
        Args:
            csv_file (string): Path to the csv file with ratings.
        """
        self.csv = pd.read_csv('drive/My Drive/Research/ratings.csv')

        self.user_ids = list(self.csv.userId-1)
        self.movie_ids = list(self.csv.movieId-1)
        self.ratings = list(self.csv.rating)

        # Count the numbers of users and movies
        self.userNums = np.max(self.user_ids)+1
        self.movieNums = np.max(self.movie_ids)+1

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, idx):
        user_idx = self.user_ids[idx]
        movie_idx = self.movie_ids[idx]
        rating = self.ratings[idx]

        concatenated = torch.tensor([user_idx, movie_idx], dtype=torch.float)

        return {
            'user_id': user_idx,
            'movie_id': movie_idx,
            'concatenated': concatenated,
            'rating': rating
        }

    def get_user_number(self):
        return self.userNums

    def get_movie_number(self):
        return self.movieNums

# %%
dataset = RatingsDataset()

train_size = int(0.6 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# %% [markdown]
# ## Model Implementation - Neural Collaborative Filtering

# %%
class NCF(Module):
    def __init__(self, num_users, num_items, first_layer=128):
        super(NCF, self).__init__()

        self.mlp = nn.Sequential(
            nn.Linear(2, first_layer),  # Input dimension is 2 since concatenated user and item indices
            nn.Dropout(0.25),
            nn.ReLU(inplace=True),
            nn.Linear(first_layer, first_layer//2),
            nn.Dropout(0.25),
            nn.ReLU(inplace=True),
            nn.Linear(first_layer//2, first_layer//4),
            nn.Dropout(0.25),
            nn.ReLU(inplace=True),
            nn.Linear(first_layer//4, 1)
        )

    def forward(self, concatenated): # Pass the concatenated data to the forward function
        return self.mlp(concatenated).squeeze()

# %% [markdown]
# ## Define Training Helper Functions

# %%
# Define the training and evaluation functions
def train(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0.0

    for batch in dataloader:
        # Pass the concatenated user-item pair as the input
        concatenated = batch['concatenated']
        # user_idx = batch['user'].to(torch.long)
        # movie_idx = batch['movie'].to(torch.long)
        # concatenated = torch.stack([user_idx, movie_idx], dim=1).to(torch.float)
        target = batch['rating'].to(torch.float)

        optimizer.zero_grad()
        output = model(concatenated)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss = 0.0

    with torch.no_grad():
        for batch in dataloader:
            concatenated = batch['concatenated']
            # user_idx = batch['user'].to(torch.long)
            # movie_idx = batch['movie'].to(torch.long)
            # concatenated = torch.stack([user_idx, movie_idx], dim=1).to(torch.float)
            target = batch['rating']

            output = model(concatenated)
            loss = criterion(output, target)

            total_loss += loss.item()

    return total_loss / len(dataloader)

# %% [markdown]
# ## Training

# %%
# Create your dataset and dataloaders
dataset = RatingsDataset()
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Instantiate your model
model = NCF(dataset.get_user_number(), dataset.get_movie_number(), first_layer=128)

# Define loss function and optimizer
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    train_loss = train(model, train_dataloader, optimizer, criterion)
    test_loss = evaluate(model, test_dataloader, criterion)
    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss = {train_loss:.4f}, Test Loss = {test_loss:.4f}")
# Out:
# Epoch 1/10: Train Loss = 8.0251, Test Loss = 1.4038
# Epoch 2/10: Train Loss = 1.1740, Test Loss = 0.9097
# Epoch 3/10: Train Loss = 0.8745, Test Loss = 0.8434
# Epoch 4/10: Train Loss = 0.8413, Test Loss = 0.8438
# Epoch 5/10: Train Loss = 0.8354, Test Loss = 0.8404
# Epoch 6/10: Train Loss = 0.8305, Test Loss = 0.8404
# Epoch 7/10: Train Loss = 0.8303, Test Loss = 0.8404
# Epoch 8/10: Train Loss = 0.8306, Test Loss = 0.8404
# Epoch 9/10: Train Loss = 0.8303, Test Loss = 0.8404
# Epoch 10/10: Train Loss = 0.8334, Test Loss = 0.8404

# %% [markdown]
# ## Produce Recommendations for a Test User

# %%
# Choose a test user ID from the MovieLens dataset
test_user_id = 125  # Replace with the actual test user ID

# Get the movies the test user has interacted with
user_interacted_items = set(item['movie_id'] for item in dataset if item['user_id'] == test_user_id)

# Generate movie recommendations for the test user
recommendations = []
for item_id in range(dataset.get_movie_number()):
    # Predict ratings for unseem movies by the test user
    if item_id not in user_interacted_items:
        concatenated = torch.tensor([[test_user_id, item_id]], dtype=torch.float)
        predicted_rating = model(concatenated).item()
        recommendations.append((item_id, predicted_rating))

# Sort recommendations by predicted rating in descending order
recommendations.sort(key=lambda x: x[1], reverse=True)

# Select the top-N recommended items
top_n_recommendations = recommendations[:500]  # Replace N with the desired number of recommendations

# Print the top-N recommended items
for item_id, predicted_rating in top_n_recommendations:
    print(f"Item ID: {item_id}, Predicted Rating: {predicted_rating:.2f}")
# Out:
# Item ID: 2, Predicted Rating: 4.00
# Item ID: 3, Predicted Rating: 4.00
# Item ID: 4, Predicted Rating: 4.00
# Item ID: 5, Predicted Rating: 4.00
# Item ID: 6, Predicted Rating: 4.00
# Item ID: 7, Predicted Rating: 4.00
# Item ID: 8, Predicted Rating: 4.00
# Item ID: 10, Predicted Rating: 4.00
# Item ID: 11, Predicted Rating: 4.00
# Item ID: 12, Predicted Rating: 4.00
# Item ID: 13, Predicted Rating: 4.00
# Item ID: 14, Predicted Rating: 4.00
# Item ID: 15, Predicted Rating: 4.00
# Item ID: 16, Predicted Rating: 4.00
# Item ID: 17, Predicted Rating: 4.00
# Item ID: 18, Predicted Rating: 4.00
# Item ID: 19, Predicted Rating: 4.00
# Item ID: 20, Predicted Rating: 4.00
# Item ID: 21, Predicted Rating: 4.00
# Item ID: 22, Predicted Rating: 4.00
# Item ID: 23, Predicted Rating: 4.00
# Item ID: 24, Predicted Rating: 4.00
# Item ID: 25, Predicted Rating: 4.00
# Item ID: 26, Predicted Rating: 4.00
# Item ID: 27, Predicted Rating: 4.00
# Item ID: 28, Predicted Rating: 4.00
# Item ID: 29, Predicted Rating: 4.00
# Item ID: 30, Predicted Rating: 4.00
# Item ID: 31, Predicted Rating: 4.00
# Item ID: 32, Predicted Rating: 4.00
# Item ID: 34, Predicted Rating: 4.00
# Item ID: 35, Predicted Rating: 4.00
# Item ID: 36, Predicted Rating: 4.00
# Item ID: 37, Predicted Rating: 4.00
# Item ID: 39, Predicted Rating: 4.00
# Item ID: 40, Predicted Rating: 4.00
# Item ID: 41, Predicted Rating: 4.00
# Item ID: 42, Predicted Rating: 4.00
# Item ID: 43, Predicted Rating: 4.00
# Item ID: 44, Predicted Rating: 4.00
# Item ID: 45, Predicted Rating: 4.00
# Item ID: 46, Predicted Rating: 4.00
# Item ID: 48, Predicted Rating: 4.00
# Item ID: 49, Predicted Rating: 4.00
# Item ID: 50, Predicted Rating: 4.00
# Item ID: 51, Predicted Rating: 4.00
# Item ID: 52, Predicted Rating: 4.00
# Item ID: 53, Predicted Rating: 4.00
# Item ID: 54, Predicted Rating: 4.00
# Item ID: 55, Predicted Rating: 4.00
# Item ID: 56, Predicted Rating: 4.00
# Item ID: 58, Predicted Rating: 4.00
# Item ID: 59, Predicted Rating: 4.00
# Item ID: 60, Predicted Rating: 4.00
# Item ID: 61, Predicted Rating: 4.00
# Item ID: 62, Predicted Rating: 4.00
# Item ID: 63, Predicted Rating: 4.00
# Item ID: 64, Predicted Rating: 4.00
# Item ID: 65, Predicted Rating: 4.00
# Item ID: 66, Predicted Rating: 4.00
# Item ID: 67, Predicted Rating: 4.00
# Item ID: 68, Predicted Rating: 4.00
# Item ID: 69, Predicted Rating: 4.00
# Item ID: 70, Predicted Rating: 4.00
# Item ID: 71, Predicted Rating: 4.00
# Item ID: 72, Predicted Rating: 4.00
# Item ID: 73, Predicted Rating: 4.00
# Item ID: 74, Predicted Rating: 4.00
# Item ID: 75, Predicted Rating: 4.00
# Item ID: 76, Predicted Rating: 4.00
# Item ID: 77, Predicted Rating: 4.00
# Item ID: 78, Predicted Rating: 4.00
# Item ID: 79, Predicted Rating: 4.00
# Item ID: 80, Predicted Rating: 4.00
# Item ID: 81, Predicted Rating: 4.00
# Item ID: 82, Predicted Rating: 4.00
# Item ID: 83, Predicted Rating: 4.00
# Item ID: 84, Predicted Rating: 4.00
# Item ID: 85, Predicted Rating: 4.00
# Item ID: 86, Predicted Rating: 4.00
# Item ID: 87, Predicted Rating: 4.00
# Item ID: 88, Predicted Rating: 4.00
# Item ID: 89, Predicted Rating: 4.00
# Item ID: 90, Predicted Rating: 4.00
# Item ID: 91, Predicted Rating: 4.00
# Item ID: 92, Predicted Rating: 4.00
# Item ID: 93, Predicted Rating: 4.00
# Item ID: 95, Predicted Rating: 4.00
# Item ID: 96, Predicted Rating: 4.00
# Item ID: 97, Predicted Rating: 4.00
# Item ID: 98, Predicted Rating: 4.00
# Item ID: 99, Predicted Rating: 4.00
# Item ID: 100, Predicted Rating: 4.00
# Item ID: 101, Predicted Rating: 4.00
# Item ID: 102, Predicted Rating: 4.00
# Item ID: 103, Predicted Rating: 4.00
# Item ID: 104, Predicted Rating: 4.00
# Item ID: 105, Predicted Rating: 4.00
# Item ID: 106, Predicted Rating: 4.00
# Item ID: 107, Predicted Rating: 4.00
# Item ID: 108, Predicted Rating: 4.00
# Item ID: 109, Predicted Rating: 4.00
# Item ID: 110, Predicted Rating: 4.00
# Item ID: 111, Predicted Rating: 4.00
# Item ID: 112, Predicted Rating: 4.00
# Item ID: 113, Predicted Rating: 4.00
# Item ID: 114, Predicted Rating: 4.00
# Item ID: 115, Predicted Rating: 4.00
# Item ID: 116, Predicted Rating: 4.00
# Item ID: 117, Predicted Rating: 4.00
# Item ID: 118, Predicted Rating: 4.00
# Item ID: 119, Predicted Rating: 4.00
# Item ID: 120, Predicted Rating: 4.00
# Item ID: 121, Predicted Rating: 4.00
# Item ID: 122, Predicted Rating: 4.00
# Item ID: 123, Predicted Rating: 4.00
# Item ID: 124, Predicted Rating: 4.00
# Item ID: 125, Predicted Rating: 4.00
# Item ID: 126, Predicted Rating: 4.00
# Item ID: 127, Predicted Rating: 4.00
# Item ID: 128, Predicted Rating: 4.00
# Item ID: 129, Predicted Rating: 4.00
# Item ID: 130, Predicted Rating: 4.00
# Item ID: 131, Predicted Rating: 4.00
# Item ID: 132, Predicted Rating: 4.00
# Item ID: 133, Predicted Rating: 4.00
# Item ID: 134, Predicted Rating: 4.00
# Item ID: 135, Predicted Rating: 4.00
# Item ID: 136, Predicted Rating: 4.00
# Item ID: 137, Predicted Rating: 4.00
# Item ID: 138, Predicted Rating: 4.00
# Item ID: 139, Predicted Rating: 4.00
# Item ID: 140, Predicted Rating: 4.00
# Item ID: 141, Predicted Rating: 4.00
# Item ID: 142, Predicted Rating: 4.00
# Item ID: 143, Predicted Rating: 4.00
# Item ID: 144, Predicted Rating: 4.00
# Item ID: 145, Predicted Rating: 4.00
# Item ID: 146, Predicted Rating: 4.00
# Item ID: 147, Predicted Rating: 4.00
# Item ID: 148, Predicted Rating: 4.00
# Item ID: 150, Predicted Rating: 4.00
# Item ID: 151, Predicted Rating: 4.00
# Item ID: 153, Predicted Rating: 4.00
# Item ID: 154, Predicted Rating: 4.00
# Item ID: 155, Predicted Rating: 4.00
# Item ID: 156, Predicted Rating: 4.00
# Item ID: 157, Predicted Rating: 4.00
# Item ID: 158, Predicted Rating: 4.00
# Item ID: 161, Predicted Rating: 4.00
# Item ID: 162, Predicted Rating: 4.00
# Item ID: 163, Predicted Rating: 4.00
# Item ID: 164, Predicted Rating: 4.00
# Item ID: 165, Predicted Rating: 4.00
# Item ID: 166, Predicted Rating: 4.00
# Item ID: 167, Predicted Rating: 4.00
# Item ID: 168, Predicted Rating: 4.00
# Item ID: 169, Predicted Rating: 4.00
# Item ID: 170, Predicted Rating: 4.00
# Item ID: 171, Predicted Rating: 4.00
# Item ID: 172, Predicted Rating: 4.00
# Item ID: 173, Predicted Rating: 4.00
# Item ID: 174, Predicted Rating: 4.00
# Item ID: 175, Predicted Rating: 4.00
# Item ID: 176, Predicted Rating: 4.00
# Item ID: 177, Predicted Rating: 4.00
# Item ID: 178, Predicted Rating: 4.00
# Item ID: 179, Predicted Rating: 4.00
# Item ID: 180, Predicted Rating: 4.00
# Item ID: 181, Predicted Rating: 4.00
# Item ID: 182, Predicted Rating: 4.00
# Item ID: 183, Predicted Rating: 4.00
# Item ID: 186, Predicted Rating: 4.00
# Item ID: 187, Predicted Rating: 4.00
# Item ID: 188, Predicted Rating: 4.00
# Item ID: 189, Predicted Rating: 4.00
# Item ID: 190, Predicted Rating: 4.00
# Item ID: 191, Predicted Rating: 4.00
# Item ID: 192, Predicted Rating: 4.00
# Item ID: 193, Predicted Rating: 4.00
# Item ID: 194, Predicted Rating: 4.00
# Item ID: 195, Predicted Rating: 4.00
# Item ID: 196, Predicted Rating: 4.00
# Item ID: 197, Predicted Rating: 4.00
# Item ID: 198, Predicted Rating: 4.00
# Item ID: 199, Predicted Rating: 4.00
# Item ID: 200, Predicted Rating: 4.00
# Item ID: 201, Predicted Rating: 4.00
# Item ID: 202, Predicted Rating: 4.00
# Item ID: 203, Predicted Rating: 4.00
# Item ID: 204, Predicted Rating: 4.00
# Item ID: 205, Predicted Rating: 4.00
# Item ID: 208, Predicted Rating: 4.00
# Item ID: 209, Predicted Rating: 4.00
# Item ID: 210, Predicted Rating: 4.00
# Item ID: 211, Predicted Rating: 4.00
# Item ID: 212, Predicted Rating: 4.00
# Item ID: 213, Predicted Rating: 4.00
# Item ID: 214, Predicted Rating: 4.00
# Item ID: 215, Predicted Rating: 4.00
# Item ID: 216, Predicted Rating: 4.00
# Item ID: 217, Predicted Rating: 4.00
# Item ID: 218, Predicted Rating: 4.00
# Item ID: 219, Predicted Rating: 4.00
# Item ID: 220, Predicted Rating: 4.00
# Item ID: 221, Predicted Rating: 4.00
# Item ID: 222, Predicted Rating: 4.00
# Item ID: 223, Predicted Rating: 4.00
# Item ID: 224, Predicted Rating: 4.00
# Item ID: 225, Predicted Rating: 4.00
# Item ID: 226, Predicted Rating: 4.00
# Item ID: 227, Predicted Rating: 4.00
# Item ID: 228, Predicted Rating: 4.00
# Item ID: 229, Predicted Rating: 4.00
# Item ID: 231, Predicted Rating: 4.00
# Item ID: 232, Predicted Rating: 4.00
# Item ID: 233, Predicted Rating: 4.00
# Item ID: 234, Predicted Rating: 4.00
# Item ID: 235, Predicted Rating: 4.00
# Item ID: 236, Predicted Rating: 4.00
# Item ID: 237, Predicted Rating: 4.00
# Item ID: 238, Predicted Rating: 4.00
# Item ID: 239, Predicted Rating: 4.00
# Item ID: 240, Predicted Rating: 4.00
# Item ID: 241, Predicted Rating: 4.00
# Item ID: 242, Predicted Rating: 4.00
# Item ID: 243, Predicted Rating: 4.00
# Item ID: 244, Predicted Rating: 4.00
# Item ID: 246, Predicted Rating: 4.00
# Item ID: 247, Predicted Rating: 4.00
# Item ID: 248, Predicted Rating: 4.00
# Item ID: 249, Predicted Rating: 4.00
# Item ID: 250, Predicted Rating: 4.00
# Item ID: 252, Predicted Rating: 4.00
# Item ID: 253, Predicted Rating: 4.00
# Item ID: 254, Predicted Rating: 4.00
# Item ID: 256, Predicted Rating: 4.00
# Item ID: 257, Predicted Rating: 4.00
# Item ID: 258, Predicted Rating: 4.00
# Item ID: 259, Predicted Rating: 4.00
# Item ID: 260, Predicted Rating: 4.00
# Item ID: 261, Predicted Rating: 4.00
# Item ID: 262, Predicted Rating: 4.00
# Item ID: 263, Predicted Rating: 4.00
# Item ID: 264, Predicted Rating: 4.00
# Item ID: 265, Predicted Rating: 4.00
# Item ID: 266, Predicted Rating: 4.00
# Item ID: 267, Predicted Rating: 4.00
# Item ID: 268, Predicted Rating: 4.00
# Item ID: 269, Predicted Rating: 4.00
# Item ID: 270, Predicted Rating: 4.00
# Item ID: 271, Predicted Rating: 4.00
# Item ID: 272, Predicted Rating: 4.00
# Item ID: 273, Predicted Rating: 4.00
# Item ID: 274, Predicted Rating: 4.00
# Item ID: 275, Predicted Rating: 4.00
# Item ID: 276, Predicted Rating: 4.00
# Item ID: 277, Predicted Rating: 4.00
# Item ID: 278, Predicted Rating: 4.00
# Item ID: 279, Predicted Rating: 4.00
# Item ID: 280, Predicted Rating: 4.00
# Item ID: 281, Predicted Rating: 4.00
# Item ID: 282, Predicted Rating: 4.00
# Item ID: 283, Predicted Rating: 4.00
# Item ID: 284, Predicted Rating: 4.00
# Item ID: 285, Predicted Rating: 4.00
# Item ID: 286, Predicted Rating: 4.00
# Item ID: 287, Predicted Rating: 4.00
# Item ID: 288, Predicted Rating: 4.00
# Item ID: 289, Predicted Rating: 4.00
# Item ID: 290, Predicted Rating: 4.00
# Item ID: 292, Predicted Rating: 4.00
# Item ID: 293, Predicted Rating: 4.00
# Item ID: 294, Predicted Rating: 4.00
# Item ID: 295, Predicted Rating: 4.00
# Item ID: 296, Predicted Rating: 4.00
# Item ID: 297, Predicted Rating: 4.00
# Item ID: 298, Predicted Rating: 4.00
# Item ID: 299, Predicted Rating: 4.00
# Item ID: 300, Predicted Rating: 4.00
# Item ID: 301, Predicted Rating: 4.00
# Item ID: 302, Predicted Rating: 4.00
# Item ID: 303, Predicted Rating: 4.00
# Item ID: 304, Predicted Rating: 4.00
# Item ID: 305, Predicted Rating: 4.00
# Item ID: 306, Predicted Rating: 4.00
# Item ID: 307, Predicted Rating: 4.00
# Item ID: 308, Predicted Rating: 4.00
# Item ID: 309, Predicted Rating: 4.00
# Item ID: 310, Predicted Rating: 4.00
# Item ID: 311, Predicted Rating: 4.00
# Item ID: 312, Predicted Rating: 4.00
# Item ID: 313, Predicted Rating: 4.00
# Item ID: 314, Predicted Rating: 4.00
# Item ID: 318, Predicted Rating: 4.00
# Item ID: 319, Predicted Rating: 4.00
# Item ID: 320, Predicted Rating: 4.00
# Item ID: 321, Predicted Rating: 4.00
# Item ID: 322, Predicted Rating: 4.00
# Item ID: 323, Predicted Rating: 4.00
# Item ID: 324, Predicted Rating: 4.00
# Item ID: 325, Predicted Rating: 4.00
# Item ID: 326, Predicted Rating: 4.00
# Item ID: 327, Predicted Rating: 4.00
# Item ID: 329, Predicted Rating: 4.00
# Item ID: 330, Predicted Rating: 4.00
# Item ID: 331, Predicted Rating: 4.00
# Item ID: 332, Predicted Rating: 4.00
# Item ID: 333, Predicted Rating: 4.00
# Item ID: 334, Predicted Rating: 4.00
# Item ID: 335, Predicted Rating: 4.00
# Item ID: 336, Predicted Rating: 4.00
# Item ID: 337, Predicted Rating: 4.00
# Item ID: 338, Predicted Rating: 4.00
# Item ID: 339, Predicted Rating: 4.00
# Item ID: 340, Predicted Rating: 4.00
# Item ID: 341, Predicted Rating: 4.00
# Item ID: 342, Predicted Rating: 4.00
# Item ID: 344, Predicted Rating: 4.00
# Item ID: 345, Predicted Rating: 4.00
# Item ID: 346, Predicted Rating: 4.00
# Item ID: 347, Predicted Rating: 4.00
# Item ID: 350, Predicted Rating: 4.00
# Item ID: 351, Predicted Rating: 4.00
# Item ID: 352, Predicted Rating: 4.00
# Item ID: 353, Predicted Rating: 4.00
# Item ID: 354, Predicted Rating: 4.00
# Item ID: 357, Predicted Rating: 4.00
# Item ID: 358, Predicted Rating: 4.00
# Item ID: 359, Predicted Rating: 4.00
# Item ID: 360, Predicted Rating: 4.00
# Item ID: 362, Predicted Rating: 4.00
# Item ID: 364, Predicted Rating: 4.00
# Item ID: 365, Predicted Rating: 4.00
# Item ID: 368, Predicted Rating: 4.00
# Item ID: 369, Predicted Rating: 4.00
# Item ID: 370, Predicted Rating: 4.00
# Item ID: 371, Predicted Rating: 4.00
# Item ID: 372, Predicted Rating: 4.00
# Item ID: 373, Predicted Rating: 4.00
# Item ID: 374, Predicted Rating: 4.00
# Item ID: 375, Predicted Rating: 4.00
# Item ID: 377, Predicted Rating: 4.00
# Item ID: 378, Predicted Rating: 4.00
# Item ID: 380, Predicted Rating: 4.00
# Item ID: 381, Predicted Rating: 4.00
# Item ID: 382, Predicted Rating: 4.00
# Item ID: 383, Predicted Rating: 4.00
# Item ID: 384, Predicted Rating: 4.00
# Item ID: 385, Predicted Rating: 4.00
# Item ID: 386, Predicted Rating: 4.00
# Item ID: 387, Predicted Rating: 4.00
# Item ID: 388, Predicted Rating: 4.00
# Item ID: 389, Predicted Rating: 4.00
# Item ID: 390, Predicted Rating: 4.00
# Item ID: 391, Predicted Rating: 4.00
# Item ID: 392, Predicted Rating: 4.00
# Item ID: 393, Predicted Rating: 4.00
# Item ID: 394, Predicted Rating: 4.00
# Item ID: 395, Predicted Rating: 4.00
# Item ID: 396, Predicted Rating: 4.00
# Item ID: 397, Predicted Rating: 4.00
# Item ID: 398, Predicted Rating: 4.00
# Item ID: 399, Predicted Rating: 4.00
# Item ID: 400, Predicted Rating: 4.00
# Item ID: 401, Predicted Rating: 4.00
# Item ID: 402, Predicted Rating: 4.00
# Item ID: 403, Predicted Rating: 4.00
# Item ID: 404, Predicted Rating: 4.00
# Item ID: 405, Predicted Rating: 4.00
# Item ID: 406, Predicted Rating: 4.00
# Item ID: 407, Predicted Rating: 4.00
# Item ID: 408, Predicted Rating: 4.00
# Item ID: 410, Predicted Rating: 4.00
# Item ID: 411, Predicted Rating: 4.00
# Item ID: 412, Predicted Rating: 4.00
# Item ID: 413, Predicted Rating: 4.00
# Item ID: 414, Predicted Rating: 4.00
# Item ID: 415, Predicted Rating: 4.00
# Item ID: 416, Predicted Rating: 4.00
# Item ID: 417, Predicted Rating: 4.00
# Item ID: 418, Predicted Rating: 4.00
# Item ID: 419, Predicted Rating: 4.00
# Item ID: 421, Predicted Rating: 4.00
# Item ID: 422, Predicted Rating: 4.00
# Item ID: 423, Predicted Rating: 4.00
# Item ID: 424, Predicted Rating: 4.00
# Item ID: 425, Predicted Rating: 4.00
# Item ID: 426, Predicted Rating: 4.00
# Item ID: 427, Predicted Rating: 4.00
# Item ID: 428, Predicted Rating: 4.00
# Item ID: 429, Predicted Rating: 4.00
# Item ID: 430, Predicted Rating: 4.00
# Item ID: 431, Predicted Rating: 4.00
# Item ID: 432, Predicted Rating: 4.00
# Item ID: 433, Predicted Rating: 4.00
# Item ID: 435, Predicted Rating: 4.00
# Item ID: 436, Predicted Rating: 4.00
# Item ID: 437, Predicted Rating: 4.00
# Item ID: 438, Predicted Rating: 4.00
# Item ID: 440, Predicted Rating: 4.00
# Item ID: 441, Predicted Rating: 4.00
# Item ID: 442, Predicted Rating: 4.00
# Item ID: 443, Predicted Rating: 4.00
# Item ID: 444, Predicted Rating: 4.00
# Item ID: 445, Predicted Rating: 4.00
# Item ID: 446, Predicted Rating: 4.00
# Item ID: 447, Predicted Rating: 4.00
# Item ID: 448, Predicted Rating: 4.00
# Item ID: 449, Predicted Rating: 4.00
# Item ID: 450, Predicted Rating: 4.00
# Item ID: 451, Predicted Rating: 4.00
# Item ID: 452, Predicted Rating: 4.00
# Item ID: 455, Predicted Rating: 4.00
# Item ID: 457, Predicted Rating: 4.00
# Item ID: 458, Predicted Rating: 4.00
# Item ID: 459, Predicted Rating: 4.00
# Item ID: 460, Predicted Rating: 4.00
# Item ID: 461, Predicted Rating: 4.00
# Item ID: 462, Predicted Rating: 4.00
# Item ID: 463, Predicted Rating: 4.00
# Item ID: 464, Predicted Rating: 4.00
# Item ID: 466, Predicted Rating: 4.00
# Item ID: 468, Predicted Rating: 4.00
# Item ID: 469, Predicted Rating: 4.00
# Item ID: 471, Predicted Rating: 4.00
# Item ID: 472, Predicted Rating: 4.00
# Item ID: 474, Predicted Rating: 4.00
# Item ID: 475, Predicted Rating: 4.00
# Item ID: 476, Predicted Rating: 4.00
# Item ID: 477, Predicted Rating: 4.00
# Item ID: 478, Predicted Rating: 4.00
# Item ID: 480, Predicted Rating: 4.00
# Item ID: 481, Predicted Rating: 4.00
# Item ID: 482, Predicted Rating: 4.00
# Item ID: 483, Predicted Rating: 4.00
# Item ID: 484, Predicted Rating: 4.00
# Item ID: 485, Predicted Rating: 4.00
# Item ID: 486, Predicted Rating: 4.00
# Item ID: 487, Predicted Rating: 4.00
# Item ID: 488, Predicted Rating: 4.00
# Item ID: 489, Predicted Rating: 4.00
# Item ID: 490, Predicted Rating: 4.00
# Item ID: 491, Predicted Rating: 4.00
# Item ID: 492, Predicted Rating: 4.00
# Item ID: 493, Predicted Rating: 4.00
# Item ID: 494, Predicted Rating: 4.00
# Item ID: 495, Predicted Rating: 4.00
# Item ID: 497, Predicted Rating: 4.00
# Item ID: 498, Predicted Rating: 4.00
# Item ID: 500, Predicted Rating: 4.00
# Item ID: 501, Predicted Rating: 4.00
# Item ID: 502, Predicted Rating: 4.00
# Item ID: 503, Predicted Rating: 4.00
# Item ID: 504, Predicted Rating: 4.00
# Item ID: 505, Predicted Rating: 4.00
# Item ID: 506, Predicted Rating: 4.00
# Item ID: 507, Predicted Rating: 4.00
# Item ID: 508, Predicted Rating: 4.00
# Item ID: 509, Predicted Rating: 4.00
# Item ID: 510, Predicted Rating: 4.00
# Item ID: 511, Predicted Rating: 4.00
# Item ID: 512, Predicted Rating: 4.00
# Item ID: 513, Predicted Rating: 4.00
# Item ID: 514, Predicted Rating: 4.00
# Item ID: 515, Predicted Rating: 4.00
# Item ID: 516, Predicted Rating: 4.00
# Item ID: 517, Predicted Rating: 4.00
# Item ID: 518, Predicted Rating: 4.00
# Item ID: 519, Predicted Rating: 4.00
# Item ID: 520, Predicted Rating: 4.00
# Item ID: 521, Predicted Rating: 4.00
# Item ID: 522, Predicted Rating: 4.00
# Item ID: 523, Predicted Rating: 4.00
# Item ID: 524, Predicted Rating: 4.00
# Item ID: 525, Predicted Rating: 4.00
# Item ID: 526, Predicted Rating: 4.00
# Item ID: 527, Predicted Rating: 4.00
# Item ID: 529, Predicted Rating: 4.00
# Item ID: 531, Predicted Rating: 4.00
# Item ID: 532, Predicted Rating: 4.00
# Item ID: 533, Predicted Rating: 4.00
# Item ID: 534, Predicted Rating: 4.00
# Item ID: 535, Predicted Rating: 4.00
# Item ID: 536, Predicted Rating: 4.00
# Item ID: 537, Predicted Rating: 4.00
# Item ID: 539, Predicted Rating: 4.00
# Item ID: 540, Predicted Rating: 4.00
# Item ID: 541, Predicted Rating: 4.00
# Item ID: 542, Predicted Rating: 4.00
# Item ID: 543, Predicted Rating: 4.00
# Item ID: 544, Predicted Rating: 4.00
# Item ID: 545, Predicted Rating: 4.00
# Item ID: 546, Predicted Rating: 4.00
# Item ID: 547, Predicted Rating: 4.00
# Item ID: 548, Predicted Rating: 4.00
# Item ID: 549, Predicted Rating: 4.00
# Item ID: 551, Predicted Rating: 4.00
# Item ID: 552, Predicted Rating: 4.00
# Item ID: 553, Predicted Rating: 4.00
